# %% [markdown]
# # TF-IDF vectorizer

# %%
# %run -i "../util/util_simple_classifier.ipynb"
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
(train_df, test_df) = load_train_test_dataset_pd()
# Out:
# Found cached dataset rotten_tomatoes (/home/zhenya/.cache/huggingface/datasets/rotten_tomatoes/default/1.0.0/40d411e45a6ce3484deed7cc15b82a53dad9a72aafd9f86f8f227134bec5ca46)
# Found cached dataset rotten_tomatoes (/home/zhenya/.cache/huggingface/datasets/rotten_tomatoes/default/1.0.0/40d411e45a6ce3484deed7cc15b82a53dad9a72aafd9f86f8f227134bec5ca46)

# %%
vectorizer = TfidfVectorizer(max_df=300)
vectorizer.fit(train_df["text"])
# Out:
# TfidfVectorizer(max_df=300)

# %%
print(vectorizer.get_feature_names_out())
print(len(vectorizer.get_feature_names_out()))
# Out:
# ['10' '100' '101' ... 'zone' 'ótimo' 'últimos']
# 8842

# %%
first_review = test_df['text'].iat[0]
dense_vector = vectorizer.transform([first_review]).todense()
print(dense_vector)
# Out:
# [[0. 0. 0. ... 0. 0. 0.]]

# %%
vectorize = lambda x: vectorizer.transform([x]).toarray()[0]
(X_train, X_test, y_train, y_test) = create_train_test_data(train_df, test_df, vectorize)
clf = train_classifier(X_train, y_train)
test_classifier(test_df, clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       160
#            1       0.74      0.78      0.76       160
#
#     accuracy                           0.75       320
#    macro avg       0.75      0.75      0.75       320
# weighted avg       0.75      0.75      0.75       320

# %% [markdown]
# # Character-based vectorizer

# %%
tfidf_char_vectorizer = TfidfVectorizer(analyzer='char_wb', ngram_range=(1,5))
tfidf_char_vectorizer = tfidf_char_vectorizer.fit(train_df["text"])

# %%
print(list(tfidf_char_vectorizer.get_feature_names_out()))
print(len(tfidf_char_vectorizer.get_feature_names_out()))
# Out:
# [' ', ' !', ' ! ', ' "', ' " ', ' $', ' $5', ' $50', ' $50-', ' $9', ' $9 ', ' &', ' & ', " '", " ' ", " '5", " '50", " '50'", " '6", " '60", " '60s", " '7", " '70", " '70'", " '70s", " '[", " '[h", " '[ho", " 'a", " 'a ", " 'a'", " 'a' ", " 'ab", " 'aba", " 'ah", " 'ah ", " 'al", " 'alt", " 'an", " 'ana", " 'ar", " 'are", " 'b", " 'ba", " 'bar", " 'be", " 'bee", " 'bes", " 'bl", " 'blu", " 'br", " 'bra", " 'bu", " 'but", " 'c", " 'ch", " 'cha", " 'co", " 'co-", " 'com", " 'd", " 'di", " 'dif", " 'do", " 'dog", " 'du", " 'dum", " 'e", " 'ed", " 'edg", " 'em", " 'em ", " 'ep", " 'epi", " 'f", " 'fa", " 'fac", " 'fat", " 'fu", " 'fun", " 'g", " 'ga
3', ' 3 ', ' 3-', ' 3-d', ' 3-d ', ' 3/', ' 3/4', ' 3/4t', ' 30', ' 30 ', ' 300', ' 3000', ' 33', ' 33-', ' 33-y', ' 3d', ' 3d ', ' 4', ' 4 ', ' 4/', ' 4/5', ' 4/5t', ' 40', ' 40-', ' 40-m', ' 40-y', ' 45', ' 45-', ' 45-m', ' 48', ' 48 ', ' 5', ' 50', ' 50-', ' 50-y', ' 51', ' 51 ', ' 6', ' 60', ' 60 ', ' 60-', ' 60-s', ' 7', ' 77', ' 77 ', ' 77-', ' 77-m', ' 8', ' 80', ' 80 ', ' 800', ' 800-', ' 82', ' 82 ', ' 84', ' 84 ', ' 85', ' 85 ', ' 86', ' 86 ', ' 9', ' 9/', ' 9/1', ' 9/11', ' 90', ' 90 ', ' 93', ' 93 ', ' 94', ' 94 ', ' 95', ' 95 ', ' 99', ' 99-', ' 99-m', ' :', ' : ', ' ;', ' ; ', ' ?', ' ? ', ' [', ' [ ', ' [a', ' [a]', ' [a] ', ' [an', ' [an]', ' [and', ' [as', ' [ass', ' [at', ' [att', ' [b', ' [bi', ' [bin', ' [br', ' [bro', ' [bu', ' [but', ' [c', ' [ch', ' [cha', ' [ci', ' [cit', ' [cl', ' [cla', ' [cr', ' [cru', ' [cry', ' [d', ' [d]', ' [d]o', ' [de', ' [den', ' [di', ' [dir', ' [dr', ' [dru', ' [e', ' [ev', ' [eva', ' [f', ' [fe', ' [fes', ' [g', ' [ga', ' [gai', ' [gr', ' [gre', ' [h', ' [ha', ' [haw', ' [he', ' [her', ' [ho', ' [how', ' [i', ' [i]', ' [i]t', ' [it', ' [it]', ' [its', ' [j', ' [ja', ' [jac', ' [jan', ' [je', ' [je-', ' [jo', ' [jon', ' [l', ' [l]', ' [l]a', ' [la', ' [law', ' [le', ' [les', ' [m', ' [mo', ' [moo', ' [n', ' [ne', ' [new', ' [næ', ' [næs', ' [o', ' [of', ' [of ', ' [on', ' [on ', ' [r', ' [ri', ' [ric', ' [s', ' [sa', ' [sad', ' [sc', ' [sch', ' [se', ' [sea', ' [see', ' [sex', ' [si', ' [sie', ' [sin', ' [so', ' [so ...
# 51270

# %%
vectorize = lambda x: tfidf_char_vectorizer.transform([x]).toarray()[0]
(X_train, X_test, y_train, y_test) = create_train_test_data(train_df, test_df, vectorize)
clf = train_classifier(X_train, y_train)
test_classifier(test_df, clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74       160
#            1       0.74      0.74      0.74       160
#
#     accuracy                           0.74       320
#    macro avg       0.74      0.74      0.74       320
# weighted avg       0.74      0.74      0.74       320
