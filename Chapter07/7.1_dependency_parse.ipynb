# %%
import spacy
from spacy import displacy

# %%
# %run -i "../util/lang_utils.ipynb"

# %%
input_text = "I shot an elephant in my pajamas."
doc = small_model(input_text)

# %%
options = {"add_lemma": True, 
        "compact": True, 
        "color": "green", 
        "collapse_punct": True, 
        "arrow_spacing": 20, 
        "bg": "#FFFFE6",
        "font": "Times",
        "distance": 120}

displacy.render(doc, style='dep', options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3779e1d902f947d2b49b5098cf32f6fc-0" class="displacy" width="890" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: green; background: #FFFFE6; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">shot</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="170">shoot</tspan>
# ...

# %%
from pathlib import Path
path = "../data/dep_parse_viz.svg"
output_path = Path(path)
svg = displacy.render(doc, style="dep", jupyter=False)
output_path.open("w", encoding="utf-8").write(svg)
# Out:
# 5517

# %%
input_text_list = "I shot an elephant in my pajamas. I hate it when elephants wear my pajamas."
doc = small_model(input_text_list)

# %%
displacy.render(list(doc.sents), style='dep', options=options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ec309dc4a5394d61b61a412c613e3d70-0" class="displacy" width="890" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: green; background: #FFFFE6; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">shot</tspan>
#     <tspan class="displacy-lemma" dy="2em" fill="currentColor" x="170">shoot</tspan>
# ...
